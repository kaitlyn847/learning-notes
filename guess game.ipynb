# %%
temp=input("不妨猜一下小甲鱼现在心里想的是哪个数字：")
guess=int(temp)

if guess==8:
    print ("good job")
    print ("猜中了也没奖励")
else:
    print ("猜错啦")

print ("game over")
# Out:
# 不妨猜一下小甲鱼现在心里想的是哪个数字： 3
# 猜错啦
# game over
